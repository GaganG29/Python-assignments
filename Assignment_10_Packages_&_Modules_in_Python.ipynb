# %% [markdown]
# <a href="https://colab.research.google.com/github/GaganG29/Python-assignments/blob/main/Assignment_10_Packages_%26_Modules_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Assignment-10: Packages & Modules in Python

# %% [markdown]
# 1. Create Two Classes in Separate Files

# %% [markdown]
# class_one.py

# %%
# %%writefile class_one.py

class ClassOne:
    def __init__(self, name):
        self.name = name
        print("ClassOne Constructor Executed")

    def display(self):
        print("Name:", self.name)
# Out:
# Writing class_one.py

# %% [markdown]
# class_two.py

# %%
# %%writefile mypackage/class_two.py

from mypackage.class_one import ClassOne

class ClassTwo:
    def __init__(self, course):
        self.course = course
        print("ClassTwo Constructor Executed")

    def display_course(self):
        print("Course:", self.course)
    def create_object(self):
        obj = ClassOne("Relative Import User")
        obj.display()
# Out:
# Writing mypackage/class_two.py
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1288/415565284.py in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('writefile', 'mypackage/class_two.py', '\nfrom mypackage.class_one import ClassOne\n\nclass ClassTwo:\n    def __init__(self, course):\n        self.course = course\n        print("ClassTwo Constructor Executed")\n\n    def display_course(self):\n        print("Course:", self.course)\n    def create_object(self):\n        obj = ClassOne("Relative Import User")\n        obj.display()\n')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     221     if line and not cell:
#     222       cell = ' '
# --> 223     return super().run_cell_magic(magic_name, line, cell)
#     224
#     225
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# <decorator-gen-98> in writefile(self, line, cell)
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/magics/osm.py in writefile(self, line, cell)
#     854
#     855         mode = 'a' if args.append else 'w'
# --> 856         with io.open(filename, mode, encoding='utf-8') as f:
#     857             f.write(cell)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'mypackage/class_two.py'

# %% [markdown]
# 2: Create a Package Folder

# %%
# !mkdir -p mypackage
# !mv class_one.py mypackage/
# !mv class_two.py mypackage/
# Out:
# mv: cannot stat 'class_two.py': No such file or directory

# %%
# %%writefile mypackage/__init__.py

from .class_one import ClassOne
from .class_two import ClassTwo
# Out:
# Writing mypackage/__init__.py

# %% [markdown]
# 3: Import Classes

# %%
import mypackage.class_one
from mypackage.class_two import ClassTwo
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_1288/3472829006.py in <cell line: 0>()
# ----> 1 import mypackage.class_one
#       2 from mypackage.class_two import ClassTwo
#
# /content/mypackage/__init__.py in <module>
#       1
#       2 from .class_one import ClassOne
# ----> 3 from .class_two import ClassTwo
#
# ModuleNotFoundError: No module named 'mypackage.class_two'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# 4. Use the Classes

# %%
obj1 = mypackage.class_one.ClassOne("Sathvika")
obj1.display()

obj2 = ClassTwo("Python")
obj2.display_course()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1288/3434117715.py in <cell line: 0>()
# ----> 1 obj1 = mypackage.class_one.ClassOne("Sathvika")
#       2 obj1.display()
#       3
#       4 obj2 = ClassTwo("Python")
#       5 obj2.display_course()
#
# NameError: name 'mypackage' is not defined

# %% [markdown]
# 5. Final Program

# %%
# %%writefile main.py
import mypackage.class_one
from mypackage.class_two import ClassTwo
print("Using ClassOne")
obj1 = mypackage.class_one.ClassOne("Sathvika")
obj1.display()
print()
print("Using ClassTwo")
obj2 = ClassTwo("Python")
obj2.display_course()
# Out:
# Writing main.py

# %%
# !python main.py
# Out:
# Traceback (most recent call last):
#   File "/content/main.py", line 1, in <module>
#     import mypackage.class_one
#   File "/content/mypackage/__init__.py", line 3, in <module>
#     from .class_two import ClassTwo
# ModuleNotFoundError: No module named 'mypackage.class_two'

# %% [markdown]
# 6. Alias Imports

# %%
import mypackage.class_one as c1

obj = c1.ClassOne("Student")
obj.display()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_1288/3224433100.py in <cell line: 0>()
# ----> 1 import mypackage.class_one as c1
#       2
#       3 obj = c1.ClassOne("Student")
#       4 obj.display()
#
# /content/mypackage/__init__.py in <module>
#       1
#       2 from .class_one import ClassOne
# ----> 3 from .class_two import ClassTwo
#
# ModuleNotFoundError: No module named 'mypackage.class_two'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# 7. Relative Imports

# %%
# %%writefile mypackage/class_two.py

from mypackage.class_one import ClassOne

class ClassTwo:
    def __init__(self, course):
        self.course = course
        print("ClassTwo Constructor Executed")

    def display_course(self):
        print("Course:", self.course)

    def create_object(self):
        obj = ClassOne("Relative Import User")
        obj.display()
# Out:
# Writing mypackage/class_two.py

# %%
import importlib
import mypackage.class_two

importlib.reload(mypackage.class_two)

from mypackage.class_two import ClassTwo

obj = ClassTwo("Python")
obj.create_object()
# Out:
# ClassTwo Constructor Executed
# ClassOne Constructor Executed
# Name: Relative Import User
